# %%
import pandas as pd
import requests

# %%
def get_movie(i):

    url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiOTUwMWFjNjhhMmQ5Y2Y3NDVlYmUwODRhNzFlMTllYyIsIm5iZiI6MTcyNjY0MjgzNy4xOTg3MTUsInN1YiI6IjY2ZWE3Nzc3ODJmZjg3M2Y3ZDFmMjM1OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Xmg-FeK6zhqjG9IevYTmyLq05r9UwHKgB1dTkNhDrmc"
    }

    response = requests.get(url, headers=headers)

    return response.json()['results']

# %%
movies = pd.DataFrame()

# %%
for i in range(1,201):
    temp_df = pd.DataFrame(get_movie(i))[['id','title','adult','overview','popularity','release_date','original_language','vote_average','vote_count',]]
    
    movies = pd.concat([movies,temp_df],axis=0).reset_index(drop=True)

# %%
movies
# Out:
#           id                           title  adult  \
# 0        278        The Shawshank Redemption  False
# 1        238                   The Godfather  False
# 2        240           The Godfather Part II  False
# 3        424                Schindler's List  False
# 4        389                    12 Angry Men  False
# ...      ...                             ...    ...
# 3995   11386                 The Crying Game  False
# 3996     919         Blood: The Last Vampire  False
# 3997  864370                     Incantation  False
# 3998  374416               Where Am I Going?  False
# 3999   10973  Creature from the Black Lagoon  False
#
#                                                overview  popularity  \
# 0     Imprisoned in the 1940s for the double murder ...     197.246
# 1     Spanning the years 1945 to 1955, a chronicle o...     120.325
# 2     In the continuing saga of the Corleone crime f...      94.615
# ...

# %%
movies.to_csv('top_rated_movies.csv',index=False)
