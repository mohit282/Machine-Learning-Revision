# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
X,y = make_regression(n_samples=1000, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature_1':X[:,0],'feature_2':X[:,1],'target':y})
df.head()
# Out:
#    feature_1  feature_2      target
# 0  -1.210564   1.690156   45.919809
# 1  -0.728260   0.922292  -42.760006
# 2   0.111240  -0.892180   -7.817159
# 3  -0.370778  -1.665443 -111.928533
# 4  -0.982135   0.921045  -86.909303

# %%
px.scatter_3d(data_frame=df, x='feature_1',y='feature_2',z='target')

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], random_state=41, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Coefficeints are : ',model.coef_)
print('Intercept is : ',model.intercept_)
# Out:
# Coefficeints are :  [65.78092598 70.75778048]
# Intercept is :  1.0676842775603346

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7715142103457769

# %% [markdown]
# #### Let's create our own multiple linear regression class

# %%
class MeraMultipleLinearRegressor:
    
    def __init__(self) ->None:
        self.coefficients = []  #beta
        self.intercept = None
    
    
    def fit(self, X_train:list[list], y_train:list[list]) ->None:
        X_train = np.insert(X_train,0,1,axis=1)
        
        beta_matrix = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.coefficients = beta_matrix[1:]
        self.intercept = beta_matrix[0]
        print(beta_matrix)
    
    def predict(self,X_test: list[list]) ->list[list]:
        
        return np.dot(X_test, self.coefficients) + self.intercept

# %%
model2 = MeraMultipleLinearRegressor()
model2.fit(X_train, y_train)
# Out:
# [ 1.06768428 65.78092598 70.75778048]

# %%
print('Coefficeints are : ',model2.coefficients)
print('Intercept is : ',model2.intercept)
# Out:
# Coefficeints are :  [65.78092598 70.75778048]
# Intercept is :  1.067684277560332

# %%
y_pred2 = model2.predict(X_test)
y_pred2
# Out:
# array([ -16.01832812,  -63.10003307, -143.84577062,  126.61127115,
#          -1.49130889,  -53.68464031,   83.74240733,   41.94891595,
#          24.38790555,  -56.85827113,   -5.78288318, -207.74636296,
#           6.61833577,   84.15868054,  100.1268868 ,  -18.47111577,
#         -79.12694056,  -18.26616463,  115.6261495 ,    6.08982994,
#         273.88688742,  -23.68379165,    9.52322445, -127.25742839,
#          81.05313624,   -3.59011189,  -57.54134132,   33.98020642,
#          84.21192536,   41.02740635,  -41.78728231,  110.59655763,
#         -44.81990371,  -28.69277415,  -85.5658219 ,   58.38094713,
#         -11.8607572 ,  -64.09841344,   79.92068322,  -87.85571743,
#          40.08164009,  162.86772872,  -43.21020248, -120.15264888,
#          13.1801037 ,  -69.73914955,  -44.55353415,  -62.39343741,
#         -97.29851175,   45.04676949,  -17.81929091,  146.84486768,
#        -171.70227688,  130.03810488,  -46.75102498,  129.63236152,
#          38.00721016,  -42.03282283,   24.18148931,   78.01374286,
#          88.86404925,   15.61809777,    3.00877697,   72.96691166,
#           6.08488278, -147.86410979,  -44.42984809,  -48.58868865,
#         193.22379789,   -8.1307484 ,   56.94011051,   76.8673145 ,
#         -31.43241722,  111.0108307 ,  -60.04427176,   18.63960289,
#        -113.085505  ,  -63.19248681,  122.85804918,  -54.96809921,
#        -106.85907492,  -81.01528544,    1.98395654,  -80.56608872,
#          87.19509651,  106.59916413,  -11.26886336,  -54.51925217,
#         132.69628081,   25.17252259,  -13.61138668,   98.39365191,
#         165.12236854,  -17.96186316,   74.98692199,  -34.4187624 ,
#        -195.90659404,   54.46390012, -151.13594252,  156.02684902,
#         -10.62952694,  -54.51885146,  -25.23115169,  144.63388519,
#           7.96435514,  146.85900556,  150.85435036,  -47.73209116,
#         136.50143282,  -82.4791665 ,   28.74927497,   68.87132507,
#        -205.98751562,  116.87449686,   95.99928351,   81.14503382,
#        -148.93054072,   17.5839621 ,  -67.89644275,   23.50980664,
#        -170.57355451,   83.76017894, -135.32885095,  -17.304992  ,
#          -2.54424437,  169.7413065 ,  -30.58431106,   89.77709538,
#        -136.30603908, -146.34748751,   -8.78454893,  -38.71646797,
#         -77.81221847,  -56.52132767,  -47.09936711,   -0.80161713,
#        -148.26180424,  211.95846401,  -93.29057961,   87.86136439,
#          -7.82832329,  -26.33152016,  -79.47363672,  -75.87242403,
#         -54.04398528,   63.33825937, -121.79337052,  105.30259958,
#          39.0337654 ,  -74.68222486,   71.13138468,   61.93774774,
#         -52.75558749,  -60.91636837,   46.26514595, -195.80240613,
#        -116.0224221 ,  -16.90508398,  -26.02820772,  -57.73404235,
#         -11.29582176,    4.99685089,  -42.90572525, -129.80087708,
#         180.1101366 ,   91.55025044,   99.03487711,  246.58621959,
#         -38.18080558,   95.52651928,   31.84151841,   80.45391641,
#         -78.98508657,   -7.26711173,  195.4033776 ,  -39.94466028,
#        -198.73314126,   20.50557591,  120.87585342,  -67.26995617,
#         -11.24554444,  104.26630276, -106.62919968, -121.75926873,
#          20.90357094,  -37.52774574,   88.71067772,   -9.85092069,
#         118.73911468,  129.97778824,  -66.7753665 ,   19.33086787,
#          75.18809033,  -48.00361928,  -30.16991053,   40.92188535,
#         -37.48563999,  155.07688816,  -43.20000038, -183.80919586])

# %%
r2_score(y_test, y_pred2) == r2_score(y_test, y_pred)
# Out:
# True
